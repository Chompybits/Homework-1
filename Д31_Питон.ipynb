# %% [markdown]
# <a href="https://colab.research.google.com/github/Chompybits/Homework-1/blob/main/%D0%9431_%D0%9F%D0%B8%D1%82%D0%BE%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание 1
# Напишите код на Python в среде Jupyter Notebook или Google Colab для решения
# следующей задачи.
# Дана переменная, в которой хранится слово из латинских букв. Напишите код, который
# выводит на экран:
# – среднюю букву, если число букв в слове нечётное;
# – две средних буквы, если число букв чётное.
# Тестирование работы программы:
# 1. word =’test' Результат: es - Тестирование прошло успешно
# 2. word = 'testing' Результат: t - Тестирование прошло успешно

# %%
word=(input('Введите слово для получения букв из середины слова '))
if len(word) < 1: #Проверим ввели ли слово.
  print('Слово для анализа не было введено')
elif len(word) == 1: #Если слово из одной буквы то просто печатаем ее.
  print(word)
elif len(word) % 2 == 1: #Используем оператор деления по модулю. Если после его применения результат будет 1 - значит в слове нечетное число букв, следовательно надо выделить одну букву по ТЗ.
  print(word[int(len(word)/2)])
elif len(word) % 2 == 0: #Используем оператор деления по модулю. Если после его применения результат будет 0 - значит в слове четное число букв, следовательно надо выделить две буквы по ТЗ.
  print(word[int(len(word)/2)-1 : int(len(word)/2)+1])

# %% [markdown]
# Задание 2.
# Напишите код на Python в среде Jupyter Notebook или Google Colab для решения
# следующей задачи.
# Вы делаете MVP (минимально жизнеспособный продукт) dating-сервиса. У вас есть
# список юношей и девушек.
# Выдвигаем гипотезу: лучшие рекомендации получатся, если просто отсортировать
# имена по алфавиту и познакомить людей с одинаковыми индексами после сортировки.
# Но вы не будете никого знакомить, если кто-то может остаться без пары.
# Примеры работы программы:
# boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
# girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
# Результат:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
# boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
# girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
# Результат: Внимание, кто-то может остаться без пары!

# %%
boys_input = input('Введите имена мальчиков, разделяя их запятыми: ') #ввод для имен мальчиков
girls_input = input('Введите имена девочек, разделяя их запятыми: ') #ввод для имен девочек
boys = [name.strip() for name in boys_input.split(',') if name.strip()] #преобразование имен мальчиков и девочек в словари. Strip удаляет все начальные и конечные пробельные символы. А split разделит слова по указанному разделителю.
girls = [name.strip() for name in girls_input.split(',') if name.strip()]
boys.sort()  #сортируем словарь мальчиков по алфавиту
girls.sort() #сортируем словарь девочек по алфавиту

if len(boys) == len(girls): #отсортировав девочек и мальчиков по алфавиту берем индексы и при равных индексах выдаем идеальные пары.
    print('Идеальные пары:')
    for i in range(len(boys)): #конкретно тут печатаем имя мальчика и имя девочки для каждого значения.
        print(f'{boys[i]} и {girls[i]}') #используем F-строку для улучшения читаемости и ускорения форматирования.
else:
    print('Внимание, кто-то может остаться без пары!') #если у нас словари разной длины то прерываем операцию и пишем что кто-то остается без пары.
